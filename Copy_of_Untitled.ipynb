# %% [markdown]
# <a href="https://colab.research.google.com/github/geetagyanani/CST_JIET_Assignments/blob/master/Copy_of_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', 50)

# %%
asp=pd.read_excel('aspiring_minds_employability_outcomes_2015.xlsx')

# %%
asp.head()
# Out:
#   Unnamed: 0      ID   Salary        DOJ                  DOL  \
# 0      train  203097   420000 2012-06-01              present
# 1      train  579905   500000 2013-09-01              present
# 2      train  810601   325000 2014-06-01              present
# 3      train  267447  1100000 2011-07-01              present
# 4      train  343523   200000 2014-03-01  2015-03-01 00:00:00
#
#                 Designation    JobCity Gender        DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f 1990-02-19          84.3
# 1         assistant manager     Indore      m 1989-10-04          85.4
# 2          systems engineer    Chennai      f 1992-08-03          85.0
# 3  senior software engineer    Gurgaon      m 1989-12-05          85.6
# 4                       get    Manesar      m 1991-02-27          78.0
#
#                           10board  12graduation  12percentage  \
# 0  board ofsecondary education,ap          2007          95.8
# ...

# %%
asp.shape
# Out:
# (3998, 39)

# %%
asp.drop('Unnamed: 0',axis=1,inplace=True)

# %%
asp.head()
# Out:
#        ID   Salary        DOJ                  DOL               Designation  \
# 0  203097   420000 2012-06-01              present   senior quality engineer
# 1  579905   500000 2013-09-01              present         assistant manager
# 2  810601   325000 2014-06-01              present          systems engineer
# 3  267447  1100000 2011-07-01              present  senior software engineer
# 4  343523   200000 2014-03-01  2015-03-01 00:00:00                       get
#
#      JobCity Gender        DOB  10percentage                         10board  \
# 0  Bangalore      f 1990-02-19          84.3  board ofsecondary education,ap
# 1     Indore      m 1989-10-04          85.4                            cbse
# 2    Chennai      f 1992-08-03          85.0                            cbse
# 3    Gurgaon      m 1989-12-05          85.6                            cbse
# 4    Manesar      m 1991-02-27          78.0                            cbse
#
# ...

# %%
asp.describe()
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
asp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   int64
#  2   DOJ                    3998 non-null   datetime64[ns]
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   datetime64[ns]
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
cat=asp.describe(include='object') #description of categorical data
noncat=asp.describe()
cat
# Out:
#             DOL        Designation    JobCity Gender 10board 12board  \
# count      3998               3998       3998   3998    3998    3998
# unique       67                419        339      2     275     340
# top     present  software engineer  Bangalore      m    cbse    cbse
# freq       1875                539        627   3041    1395    1400
#
#              Degree                             Specialization   CollegeState
# count          3998                                       3998           3998
# unique            4                                         46             26
# top     B.Tech/B.E.  electronics and communication engineering  Uttar Pradesh
# freq           3700                                        880            915

# %% [markdown]
# ## Observation 1
# * it seems like most people are from B.Tech/B.E degree.
# * Most people are from electronics and communication engineering Specialization.
# * Most people had cbse board in 10th and 12th.

# %%
#just plotting graphs to show how it will look like
sns.set()
plt.hist(asp['Specialization'],bins=25)
plt.xticks(rotation='vertical')
plt.title('Specialization Histogram')
plt.show()
print('Percentage wise:')
asp['Specialization'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# electronics and communication engineering      22.011
# computer science & engineering                 18.609
# information technology                         16.508
# computer engineering                           15.008
# computer application                            6.103
# mechanical engineering                          5.028
# electronics and electrical engineering          4.902
# electronics & telecommunications                3.027
# electrical engineering                          2.051
# electronics & instrumentation eng               0.800
# civil engineering                               0.725
# electronics and instrumentation engineering     0.675
# information science engineering                 0.675
# instrumentation and control engineering         0.500
# electronics engineering                         0.475
# biotechnology                                   0.375
# other                                           0.325
# ...

# %% [markdown]
# ## Observation 2
# *It shows 22.01 % Students are from ECE and 18.09 % are from CSE and it shows percentage of other branches also.

# %%
sns.set()
plt.hist(asp['Degree'],bins=25)
plt.xticks(rotation='vertical')
plt.title('Degree Histogram')
plt.show()
print('Percentage wise:')
asp['Degree'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# B.Tech/B.E.      92.546
# MCA               6.078
# M.Tech./M.E.      1.326
# M.Sc. (Tech.)     0.050
# Name: Degree, dtype: float64

# %% [markdown]
# # Observation 2
# * It shows 92.54 % Students are from B.Tech/B.E and 6.078 % are from MCA and it shows other results too.

# %%
print('Percentage wise:')
asp['Designation'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# software engineer                    13.482
# software developer                    6.628
# system engineer                       5.128
# programmer analyst                    3.477
# systems engineer                      2.951
#                                       ...
# associate manager                     0.025
# delivery software engineer            0.025
# junior system analyst                 0.025
# secretary                             0.025
# senior quality assurance engineer     0.025
# Name: Designation, Length: 419, dtype: float64

# %%
sns.set()
plt.hist(asp['CollegeState'],bins=50)
plt.xticks(rotation='vertical')
plt.title('CollegeState Histogram')
plt.show()
print('Percentage wise:')
asp['CollegeState'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# Uttar Pradesh        22.886
# Karnataka             9.255
# Tamil Nadu            9.180
# Telangana             7.979
# Maharashtra           6.553
# Andhra Pradesh        5.628
# West Bengal           4.902
# Punjab                4.827
# Madhya Pradesh        4.727
# Haryana               4.502
# Rajasthan             4.352
# Orissa                4.302
# Delhi                 4.052
# Uttarakhand           2.826
# Kerala                0.825
# Jharkhand             0.700
# Chhattisgarh          0.675
# Gujarat               0.600
# Himachal Pradesh      0.400
# Bihar                 0.250
# Jammu and Kashmir     0.175
# Union Territory       0.125
# Assam                 0.125
# Sikkim                0.075
# Meghalaya             0.050
# Goa                   0.025
# Name: CollegeState, dtype: float64

# %%
#	Degree Designation	Specialization CollegeState JobCity	Gender	10board	12board			DOL


print('Percentage wise:')
asp['JobCity'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# Bangalore    15.683
# -1           11.531
# Noida         9.205
# Hyderabad     8.379
# Pune          7.254
#               ...
# angul         0.025
# BANGLORE      0.025
# Madurai       0.025
# punr          0.025
# Punchkula     0.025
# Name: JobCity, Length: 339, dtype: float64

# %%
sns.countplot(x='Gender', data=asp)

# %%
print('Percentage wise:')
asp['10board'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# cbse                                     34.892
# state board                              29.115
# 0                                         8.754
# icse                                      7.029
# ssc                                       3.052
#                                           ...
# bihar secondary education board,patna     0.025
# cluny                                     0.025
# andhra pradesh state board                0.025
# jbse,jharkhand                            0.025
# secondary school certificate              0.025
# Name: 10board, Length: 275, dtype: float64

# %%
print('Percentage wise:')
asp['12board'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# cbse                                      35.018
# state board                               31.366
# 0                                          8.979
# icse                                       3.227
# up board                                   2.176
#                                            ...
# holy cross matriculation hr sec school     0.025
# cicse                                      0.025
# intermediate council patna                 0.025
# gseb/technical education board             0.025
# tamilnadu stateboard                       0.025
# Name: 12board, Length: 340, dtype: float64

# %% [markdown]
# # For numerical data

# %%
noncat
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  3.076998e+05     77.925443   2008.087544     74.466366
# std    3.632182e+05  2.127375e+05      9.850162      1.653599     10.999933
# min    1.124400e+04  3.500000e+04     43.000000   1995.000000     40.000000
# 25%    3.342842e+05  1.800000e+05     71.680000   2007.000000     66.000000
# 50%    6.396000e+05  3.000000e+05     79.150000   2008.000000     74.400000
# 75%    9.904800e+05  3.700000e+05     85.670000   2009.000000     82.600000
# max    1.298275e+06  4.000000e+06     97.760000   2013.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.486171    5156.851426         0.300400
# ...

# %%
#
# from the above observation we can say,outliers are present in data in columns CollegeID, CollegeCityID, CollegeCityTier, ElectronicsAndSemicon , ComputerScience, MechanicalEngg , ElectricalEngg , TelecomEngg , CivilEngg, conscientiousness, agreeableness, extraversion
# IQR range for these columns ComputerScience ,MechanicalEngg, ElectricalEngg, TelecomEngg ,CivilEngg is -1 ,there are outliers definitely.
#  There are many other observations too like avg 10th and 12th percentage are 77.92% and 74.46 %  respectively 
# ElectronicsAndSemicon ,ComputerScience are having maximum avg percentage

# %% [markdown]
# # Probabality distribution

# %%
f, axs = plt.subplots(1,2,figsize=(18,7))
plt.subplot(1,2,1)
plt.title('Salary PDF')
sns.distplot(asp['Salary'], hist=True, rug=False)
plt.subplot(1,2,2)
plt.title('Salary boxplot')
sns.boxplot(asp['Salary'])

# %%
# maxmimum people are having salary less than 600000
# People having salary more than 750000 are outliers
#The histogram shows frequency distribution of Salary.

# %%
#ID	Salary	10percentage	12graduation	12percentage	CollegeID	CollegeTier	collegeGPA	CollegeCityID	CollegeCityTier	GraduationYear	English	Logical	Quant	Domain	ComputerProgramming	ElectronicsAndSemicon	ComputerScience	MechanicalEngg	ElectricalEngg	TelecomEngg	CivilEngg	conscientiousness	agreeableness	extraversion	nueroticism	openess_to_experience
f, axs = plt.subplots(1,2,figsize=(18,7))
plt.subplot(1,2,1)
plt.title('10percentage PDF')
sns.distplot(asp['10percentage'], hist=True, rug=False)
plt.subplot(1,2,2)
plt.title('10percentage boxplot')
sns.boxplot(asp['10percentage'])

# %%
f, axs = plt.subplots(1,2,figsize=(18,7))
plt.subplot(1,2,1)
plt.title('12percentage PDF')
sns.distplot(asp['12percentage'], hist=True, rug=False)
plt.subplot(1,2,2)
plt.title('12percentage boxplot')
sns.boxplot(asp['12percentage'])

# %%
f, axs = plt.subplots(1,2,figsize=(18,7))
plt.subplot(1,2,1)
plt.title('12graduation PDF')
sns.distplot(asp['12graduation'], hist=True, rug=False)
plt.subplot(1,2,2)
plt.title('12graduation')
sns.boxplot(asp['12graduation'])

# %%
f, axs = plt.subplots(1,2,figsize=(18,7))
plt.subplot(1,2,1)
plt.title('collegeGPA PDF')
sns.distplot(asp['collegeGPA'], hist=True, rug=False)
plt.subplot(1,2,2)
plt.title('collegeGPA boxplot')
sns.boxplot(asp['collegeGPA'])

# %%
print('Percentage wise:')
asp['CollegeTier'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# 2    92.571
# 1     7.429
# Name: CollegeTier, dtype: float64

# %%
f, axs = plt.subplots(1,2,figsize=(18,7))
plt.subplot(1,2,1)
plt.title('GraduationYear PDF')
sns.distplot(asp['GraduationYear'], hist=True, rug=False)
plt.subplot(1,2,2)
plt.title('GraduationYear boxplot')
sns.boxplot(asp['GraduationYear'])
print('Percentage wise:')
asp['GraduationYear'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# 2013    29.540
# 2014    25.913
# 2012    21.186
# 2011    12.681
# 2010     7.304
# 2015     2.351
# 2009     0.600
# 2017     0.200
# 2016     0.175
# 2007     0.025
# 0        0.025
# Name: GraduationYear, dtype: float64

# %%
#CollegeCityTier
print('Percentage wise:')
asp['CollegeCityTier'].value_counts(1).apply(lambda i:round(i*100,3))
# Out:
# Percentage wise:
# 0    69.96
# 1    30.04
# Name: CollegeCityTier, dtype: float64

# %%
listt=['English','Logical','Quant','Domain','ComputerProgramming','ElectronicsAndSemicon','conscientiousness','agreeableness','extraversion','nueroticism','openess_to_experience']
for i in listt:
    f, axs = plt.subplots(1,2,figsize=(18,7))
    plt.subplot(1,2,1)
    plt.title(i)
    sns.distplot(asp[i], hist=True, rug=False)
    plt.subplot(1,2,2)
    plt.title(i)
    sns.boxplot(asp[i])

# %%
asp.ComputerScience.value_counts()
# Out:
# -1      3096
#  407     128
#  376     123
#  346     118
#  438     111
#  469      80
#  315      77
#  500      64
#  284      50
#  530      45
#  253      30
#  561      22
#  592      14
#  223      14
#  623      10
#  653       9
#  192       3
#  715       2
#  684       1
#  130       1
# Name: ComputerScience, dtype: int64

# %%
asp.MechanicalEngg.value_counts()
# Out:
# -1      3763
#  366      20
#  446      16
#  438      15
#  420      14
#  393      13
#  376      13
#  313      13
#  407      12
#  346      11
#  469      10
#  473      10
#  553       8
#  435       7
#  383       6
#  340       6
#  286       5
#  526       5
#  409       5
#  253       4
#  500       4
#  332       3
#  538       3
#  284       3
#  580       3
#  254       3
#  512       2
#  561       2
#  564       2
#  606       2
#  223       2
#  260       2
#  616       2
#  280       1
#  206       1
#  623       1
#  306       1
#  358       1
#  233       1
#  315       1
#  461       1
#  180       1
# Name: MechanicalEngg, dtype: int64

# %%
asp.ElectricalEngg.value_counts()
# Out:
# -1      3837
#  420      16
#  446      14
#  452      10
#  473      10
#  388      10
#  356       9
#  500       8
#  580       8
#  366       7
#  324       7
#  393       7
#  313       6
#  553       6
#  516       5
#  292       4
#  260       4
#  340       3
#  228       3
#  633       3
#  484       3
#  526       3
#  548       2
#  606       2
#  612       2
#  660       2
#  286       2
#  433       2
#  676       1
#  411       1
#  206       1
# Name: ElectricalEngg, dtype: int64

# %%
asp.TelecomEngg.value_counts()
# Out:
# -1      3624
#  393      45
#  366      43
#  260      35
#  313      34
#  340      32
#  286      31
#  420      26
#  446      16
#  233      14
#  388      14
#  292      13
#  473      13
#  356      12
#  324      11
#  206       8
#  500       5
#  526       5
#  484       4
#  516       4
#  228       3
#  548       2
#  452       1
#  153       1
#  196       1
#  164       1
# Name: TelecomEngg, dtype: int64

# %%
asp.CivilEngg.value_counts()
# Out:
# -1      3956
#  356       6
#  292       6
#  388       4
#  260       3
#  320       3
#  500       2
#  300       2
#  340       2
#  200       1
#  280       1
#  322       1
#  433       1
#  380       1
#  277       1
#  400       1
#  420       1
#  440       1
#  452       1
#  460       1
#  480       1
#  516       1
#  166       1
# Name: CivilEngg, dtype: int64

# %% [markdown]
# # Bivariate Analysis:¶
# ## description

# %%
data_desc=asp.describe(include='all')
data_desc
# Out:
#                   ID        Salary                  DOJ      DOL  \
# count   3.998000e+03  3.998000e+03                 3998     3998
# unique           NaN           NaN                   81       67
# top              NaN           NaN  2014-07-01 00:00:00  present
# freq             NaN           NaN                  199     1875
# first            NaN           NaN  1991-06-01 00:00:00      NaN
# last             NaN           NaN  2015-12-01 00:00:00      NaN
# mean    6.637945e+05  3.076998e+05                  NaN      NaN
# std     3.632182e+05  2.127375e+05                  NaN      NaN
# min     1.124400e+04  3.500000e+04                  NaN      NaN
# 25%     3.342842e+05  1.800000e+05                  NaN      NaN
# 50%     6.396000e+05  3.000000e+05                  NaN      NaN
# 75%     9.904800e+05  3.700000e+05                  NaN      NaN
# max     1.298275e+06  4.000000e+06                  NaN      NaN
#
# ...

# %% [markdown]
# ## Salary based upon Designation

# %%
print('Percentage of Designations:')
asp['Designation'].value_counts(1).apply(lambda n:round(n*100,3))
# Out:
# Percentage of Designations:
# software engineer                    13.482
# software developer                    6.628
# system engineer                       5.128
# programmer analyst                    3.477
# systems engineer                      2.951
#                                       ...
# associate manager                     0.025
# delivery software engineer            0.025
# junior system analyst                 0.025
# secretary                             0.025
# senior quality assurance engineer     0.025
# Name: Designation, Length: 419, dtype: float64

# %%
sns.pairplot(asp)

# %%
sns.stripplot(data = asp, x = 'Gender', y='Salary')

# %%
plt.figure(figsize=(20, 100))
plt.scatter( asp['Gender'],asp['Designation'])
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.boxplot( x=asp['Gender'], y=asp['Salary'])

# %%
plt.figure(figsize=(20, 100))
plt.scatter(asp['Salary'], asp['Designation'])
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.boxplot( x=asp['CollegeTier'], y=asp['Salary'])

# %%
plt.figure(figsize=(20, 100))
plt.scatter(asp['10percentage'], asp['Salary'])
plt.show()

# %%
sns.stripplot(data = asp, x = 'Gender', y='10percentage')

# %%
sns.stripplot(data = asp, x = 'Gender', y='12percentage')

# %%
plt.figure(figsize=(25, 8))
sns.lineplot(x = 'Salary', y = 'CollegeTier', hue='Gender', data = asp)
plt.title('Salary of Each gender for whole College Tier ')
# Out:
# Text(0.5, 1.0, 'Salary of Each gender for whole College Tier ')

# %%
#Feature Transform

# %%
#1. Dealing with Numeric Variables:


# just to check type of numerical var
asp[asp.dtypes[(asp.dtypes=="int64")].index.values].hist(figsize=[20,16])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0da9b22198>,
# ...
#       dtype=object)

# %%
#Now let's do feature transform


from sklearn import preprocessing
n_test = asp[['ID','Salary','DOJ','Designation','JobCity','Gender','DOB','10percentage','10board','12graduation','12percentage','12board','CollegeID','CollegeTier']] #list of test data
cols_to_norm = ['ID','Salary','DOJ','Designation','JobCity','Gender','DOB','10percentage','10board','12graduation','12percentage','12board','CollegeID','CollegeTier'] #cols to normalize
x = n_test.values
mm_scaler = preprocessing.MinMaxScaler()
x_scaled = mm_scaler.fit_transform(x)
n_test = pd.DataFrame(x_scaled, columns=cols_to_norm)
l_test = data.drop(['ID','Salary','DOJ','Designation','JobCity','Gender','DOB','10percentage','10board','12graduation','12percentage','12board','CollegeID','CollegeTier'], axis=1)
asp = pd.concat([n_test, l_test], axis=1)
asp.columns

# %%
#2. Dealing with categorical var


dummy_cols = ['DOL','Designation','JobCity','Gender','10board','12board','Degree','Specialization','CollegeState']
asp = pd.get_dummies(asp, columns = dummy_cols)
